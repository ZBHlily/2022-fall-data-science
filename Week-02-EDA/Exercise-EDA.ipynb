# %% [markdown]
# # Exploratory Data Analysis Exercise
# * For this part we will be using the `data/cars.csv` dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline 
import scipy.stats as stats

# %% [markdown]
# # Load in the data
# * Use the file in the data folder called 'cars.csv'
# * Save it as a varible named 'df'
# * Display the first 5 rows of our dataframe

# %%
# Load data
df = pd.read_csv('data/cars.csv')
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# ...

# %% [markdown]
# # Data clean up part 1.
#
# 1. Print the number of duplicate rows we have in our dataframe.
#
# 2. Modify our df to have all duplicate rows removed.
#
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.

# %%
# 1. Print the number of duplicate rows we have in our dataframe.
print(df.duplicated().sum())
df.duplicated()
# Out:
# 720
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
#  2. Modify our df to have all duplicate rows removed. 
print("before:",df.shape)
df = df.drop_duplicates()
# Out:
# before: (11914, 15)

# %%
# 3. Do a sanity check to make sure all duplicates have been removed by printing the total number of duplicate rows again.
print("after:",df.shape)
print(df.duplicated().sum())
# Out:
# after: (11194, 15)
# 0

# %% [markdown]
# # Data clean up part 2.
# * Which column has the most null values and how many null values does it have?
# * Print how long our dataframe is.
# * Remove any row that has a null value in it.
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.

# %%
# * Which column has the most null values and how many null values does it have?
df.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine Fuel Type      3
# Engine HP            69
# Engine Cylinders     30
# Transmission Type     0
# Driven_Wheels         0
# Number of Doors       6
# Vehicle Size          0
# Vehicle Style         0
# highway MPG           0
# city mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
# * Print how long our dataframe is.
df.shape
# Out:
# (11194, 15)

# %%
# * Remove any row that has a null value in it. 
print(df.shape)

# df.dropna(inplace=True)
df = df.dropna()
# Out:
# (11194, 15)

# %%
# * Do a sanity check and pring how long our dataframe is now that we have removed our null values.
# Sanity Check
print(df.shape)

# pring how many null values there are
df.isnull().sum()
# Out:
# (11092, 15)
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# ### Make a bar chart that displays how many times each brand of car appears in this data.
# _Brand of car is the `Make` of the car._
# * You can achieve this by using value_counts or by a groupby.  Either is fine with me.

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Vehicle Size', 'Vehicle Style', 'highway MPG',
#        'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
# Make a bar chart that displays how many times each brand of car appears in this data. 
gb = df.groupby("Make")
gb_count = gb["Make"].count() 
gb_count.plot(kind = "bar", figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
brand_count = df['Make'].value_counts()
brand_count.plot(kind ='bar', figsize=(10, 5)) # in highest to lowest order
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Make the cart more legible, by making it a horizontal bar chart and changing the figure size.  And also sort the values so the bar chart displays from lowest to highest.

# %%
# Make the cart more legible, by making it a horizontal bar chart, sorting the values, and changing the figure size.
gb.plot(kind='barh', figsize=(15,10))
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:345: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# Year
# 1990    AxesSubplot(0.125,0.125;0.775x0.755)
# 1991    AxesSubplot(0.125,0.125;0.775x0.755)
# 1992    AxesSubplot(0.125,0.125;0.775x0.755)
# 1993    AxesSubplot(0.125,0.125;0.775x0.755)
# 1994    AxesSubplot(0.125,0.125;0.775x0.755)
# 1995    AxesSubplot(0.125,0.125;0.775x0.755)
# 1996    AxesSubplot(0.125,0.125;0.775x0.755)
# 1997    AxesSubplot(0.125,0.125;0.775x0.755)
# 1998    AxesSubplot(0.125,0.125;0.775x0.755)
# 1999    AxesSubplot(0.125,0.125;0.775x0.755)
# 2000    AxesSubplot(0.125,0.125;0.775x0.755)
# 2001    AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %%
# highest to lowest 
gb = df.groupby("Make")
gb_count = gb["Make"].count().sort_values()
gb_count.plot(kind = "barh", figsize = (13, 21))
# Out:
# <AxesSubplot:ylabel='Make'>

# %% [markdown]
# # Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
# * What's noticeable about it and what do you think the error is...

# %%
# Make a timeline line chart in which the x-axis is the year, and the y-axis is the average MSRP.
gb = df.groupby(["Year"])
avg_MSRP = gb["MSRP"].mean()
avg_MSRP.plot()

# avg car of 1990 --> are they less than 10k  
# says avg price is 30k --> wrong
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df.head(10)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %% [markdown]
# # It seems as though in the years before (and includig) 2000, they were counting in tens.
# Make a new column that is called `adjusted_price`, that contains all prices, however, for every year before 2000 make it 10x the original MSRP.
#    * Hint; you might need to use our old friend `np.where`

# %%
# Make a column where is 10 when year is less than 2000, else 1.
# Multiply the MSRP by the price adjuster.

def adjust_price_year(x):
    if x <= 2000:
        return 10
    else:
        return 1
    
df["adjusted_price"] = df["MSRP"]
df["adjusted_price"] *= df["Year"].apply(adjust_price_year)

df.head()

# or
# cond = df['Year'] < 2000
# df["adjusted_price"] = np.where( cond, df["MSRP"]*10, df["MSRP"])
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#   Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity   MSRP  \
# ...

# %% [markdown]
# # Replot the new adjusted price.
# * Make the y-axis start at 0 and go up to 100,000

# %%
# Plot new prices
gb = df.groupby("Year")
avg_MSRP = gb["adjusted_price"].mean()
avg_MSRP.plot(kind = "line", figsize = (8,5))
avg_MSRP.set_ylim = (0, 100000)

# %% [markdown]
# # What are top 5 car makers that make the most expensive cars on average.
# * I only want the top 5, make sure your answer is the top 5 and only the top 5. (hint, you can use .head())
# * Use our `adjusted_price` column for this
# * Hint; you're going to have to do a .groupby to answer this.

# %%
# What are the top 5 car makers make the most expensive cars on average. 
gb = df.groupby("Make")
count_makes = gb["adjusted_price"].mean().sort_values(ascending=False).head()
count_makes[:5].plot(kind = "barh")
# Out:
# <AxesSubplot:ylabel='Make'>

# %% [markdown]
# # What are the 5 car makers that have the highest median highway MPG?

# %%
# Which car makers have the highest median highway MPG?
gb = df.groupby("Make")
count_makes = gb["highway MPG"].median().sort_values(ascending=False).head()
count_makes[:5].plot(kind = "barh")
# Out:
# <AxesSubplot:ylabel='Make'>

# %% [markdown]
# # Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
# * ['Chevrolet', 'Ford', 'Toyota']
# * Create a temp_df to store the dataframe of just these values.
# * Set the 'hue='Make''.

# %%
# Using `sns.histplot`, make histogram of the adjusted_price of just these car makers.
import seaborn as sns
temp_df = df.loc[df["Make"].isin(['Chevrolet', 'Ford', 'Toyota'])]
ax = sns.histplot(data = temp_df, x = "adjusted_price", hue = "Make")

# %% [markdown]
# # Remake the same histogram, but limit the x-axis from 0 to 100,000

# %%
# Remake the same histogram, but limit the x-axis from 0 to 100,000
temp_df = df.loc[df["Make"].isin(['Chevrolet', 'Ford', 'Toyota'])]
ax = sns.histplot(data = temp_df, x = "adjusted_price", hue = "Make")
ax.set_xlim(0, 100000)
# Out:
# (0.0, 100000.0)

# %% [markdown]
# # Plot the relationship between Engine HP and highway MPG

# %%
# Plot the relationship between Engine HP and highway MPG
relationship_ehp_hmpg = sns.scatterplot(data = df, x = "Engine HP", y = "highway MPG")

# %% [markdown]
# # Using `sns.boxplot`, create a boxplot for the 'Engine HP'

# %%
# create a boxplot for the 'Engine HP'
ax = sns.boxplot(data = df, x = "Engine HP")

# %% [markdown]
# # Make another boxplot for highway MPG

# %%
# create a boxplot for the 'highway MPG'
ax = sns.boxplot(data = df, x = "highway MPG")

# %% [markdown]
# # Remove any  outliers from Engine HP and highway MPG
#
# <img src='https://miro.medium.com/max/1400/1*2c21SkzJMf3frPXPAR_gZA.png' width=500>
#
# * Outliers meaning values that are outside 1.5x the Inter Quartile Range (see image above).
# * For each column (Engine HP and highway MPG):
# * Calculate the 0.25 and 0.75 Quantiles
# * Calculate the Inter Quartile Range (IQR)
# * Create condition mask for the values that are outliers below (in the 'Minimum' range).
# * Create condition mask for the values that are outliers above (in the 'Maximum' range).
# * Filter the dataframe to remove any values that are in the above section _OR_ the below section. (hint; it may be easier to use the inverse selection '~'.
# * Make the same boxplots of Engine HP and Highway MPG as before but with the this dataframe.

# %%
df.describe()
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11092.000000  11092.000000      11092.000000     11092.000000
# mean    2010.693833    253.528579          5.687973         3.450415
# std        7.241249    110.184621          1.766331         0.874700
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    172.000000          4.000000         2.000000
# 50%     2015.000000    240.000000          6.000000         4.000000
# 75%     2016.000000    303.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP  adjusted_price
# count  11092.000000  11092.000000  11092.000000  1.109200e+04    1.109200e+04
# mean      26.272899     19.300667   1556.681302  4.190853e+04    4.452138e+04
# std        7.481404      6.605683   1443.586149  6.174305e+04    6.101174e+04
# ...

# %%
# Remove any  outliers from Engine HP and highway MPG 
Q1_eHP = df["Engine HP"].quantile(0.25)
Q1_hMPG = df["highway MPG"].quantile(0.25)

Q3_eHP = df["Engine HP"].quantile(0.75)
Q3_hMPG = df["highway MPG"].quantile(0.75)

IQR_eHP = Q3_eHP - Q1_eHP
IQR_hMPG = Q3_hMPG - Q1_hMPG

eHP_outliers_below = df['Engine HP'] < (Q1_eHP - 1.5 * IQR_eHP)
hMPG_outliers_below = df['highway MPG'] < (Q1_hMPG - 1.5 * IQR_hMPG)

eHP_outliers_above = df['Engine HP'] > (Q3_eHP + 1.5 * IQR_eHP)
hMPG_outliers_above = df['highway MPG'] > (Q3_hMPG + 1.5 * IQR_hMPG)

df_eHP = df[ ~(eHP_outliers_above | eHP_outliers_below) ]
df_hMPG = df[ ~(hMPG_outliers_above | hMPG_outliers_below) ]

# %% [markdown]
# # Remake the boxplots for both Engine HP and highway MPG

# %%
# Engine HP boxplot
ax = sns.boxplot(data = df_eHP, x = "Engine HP")

# %%
# highway MPG boxplot
ax = sns.boxplot(data = df_hMPG, x = "highway MPG")

# %% [markdown]
# # Make a scatter plot of Engine HP vs highway MPG

# %%
# Make a scatter plot of Engine HP vs highway MPG
df_combine = df_hMPG + df_eHP
ax_ehp_hmpg = sns.scatterplot(data = df_combine, x = "Engine HP", y = "highway MPG", hue = "Engine HP")

# %% [markdown]
# # What does this plot tell you about how Engine HP affects highway MPG?

# %%
# What does this plot tell you about how Engine HP affects highway MPG?
print("it shows us that the higher the Engine HP, the lower the Highway HPG is so it's a negative correlation")
# Out:
# it shows us that the higher the Engine HP, the lower the Highway HPG is so it's a negative correlation

# %% [markdown]
# # Using a pairplot, display all of the linear relationship.
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).

# %%
# Using a pairplot, display all of the linear relationship.
sns.pairplot(df)

# %%
# * Which variables look like they have the strongest linear relationship (Besides MSRP and adjusted_price).
print("the variables with the strongest linear relationship is city mpg vs highway MPG")
# Out:
# the variables with the strongest linear relationship is city mpg vs highway MPG

# %% [markdown]
# # Find which features actually have the strongest linear relationship using correlations.
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
# * __Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.__

# %%
# * Make a heatmap plot of all of the correlations in our dataset.
# * Change the figure size of our heatmap plot to be 8x8
heatmap_plot = plt.subplots(figsize = (8,8))
heatmap_plot = sns.heatmap(df.corr(), cmap = "coolwarm", annot = True)

# %%
# Which feature does Engine HP have the strongest relationship with, and why do you think that relationship exists.
print('The strongest relationship with Engine HP would be Engine Cylinders. This is because the bigger the engine cylinders, the more engine HP power is produced')
# Out:
# The strongest relationship with Engine HP would be Engine Cylinders. This is because the bigger the engine cylinders, the more engine HP power is produced

# %% [markdown]
# # [EXTRA CREDIT]
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well

# %%
# * In the column names, replace all the spaces with an underscore, and make them all lowercase as well
