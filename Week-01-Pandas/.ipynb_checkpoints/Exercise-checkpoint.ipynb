# %% [markdown]
# # Data wrangling with Pandas exercise
# * For this exercise we will be using the `listings.csv` data file.

# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in the data file using `pd.read_csv()`

# %%
# Load data here
df = pd.read_csv('data/listings.csv')
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ## Exercise 2 - Filtering
#
# Return the following subsets of the dataframe.
#
# 1. How many listings are there with a price less than 100?
#
#
# 2. Find how many listings there are in just Brooklyn.
#
#
# 3. Find how many listings there are in Brooklyn with a price less than 100.
#
#
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
#
#
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  The prices for all other listings should be the same as the were before.
#
#
# 6. What % of the rooms are private, and what % of the rooms are shared.
#     * Hint, use `.value_counts()`

# %%
# 1. How many listings are there with a price less than 100? 
condition = df.price < 100
len(df[condition])
# Out:
# 22778

# %%
# 2. Make a new DataFrame of listings in Brooklyn named `df_bk` 
# and find how many listings in just Brooklyn.
df_bk = df['neighbourhood_group'] == 'Brooklyn'
len(df[df_bk])
# Out:
# 18632

# %%
# 3. Find how many listings there are in Brooklyn with a price less than 100.

# selecting Brooklyn
condition_1 = df['neighbourhood_group'] == 'Brooklyn'

# select Prices that are less than 100
condition_2 = df['price'] < 100

# select all data that meets both requirments
len(df[condition_1 & condition_2])
# Out:
# 10473

# %%
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.

# selecting list of names
host_names = ['Michael', 'David', 'John', 'Daniel']

# creating selection condition 
condition = df.host_name.isin(host_names)

# display those who have the host name of ...
df[condition]
df[condition]['host_name'].value_counts()
# Out:
# Michael    387
# David      348
# John       270
# Daniel     253
# Name: host_name, dtype: int64

# %%
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  

c1 = df['neighbourhood'] == 'Williamsburg'

# set equal to 100 when both conditions are true, and zero when not true.
df['williamsburg_fee'] = np.where(c1, 100, 0)
df['adjusted_price'] = df['price'] + df['williamsburg_fee']
df[c1].head(2)

# or
# c1 = df['neighbourhood'] == 'Williamsburg'
# df['adjusted_price'] = np.where(c1, df['price'] + 100, df['price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/t5/961m25k976xdp4w3m8b1r5600000gn/T/ipykernel_91738/3662135671.py in <module>
#       1 # 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.
#       2
# ----> 3 c1 = df['neighbourhood'] == 'Williamsburg'
#       4
#       5 # set equal to 100 when both conditions are true, and zero when not true.
#
# NameError: name 'df' is not defined

# %%
# 6. What % of the rooms are private, and what % of the rooms are shared.  

df_private_rooms = df.room_type.value_counts() / df.room_type.value_counts().sum()
df_private_rooms

# or
# private_rooms = df['room_type'] == "Private room"
# shared_rooms =  df['room_type'] == "Shared room"

# private_percent = len(df[private_rooms]) / len(df)
# shared_percent = len(df[shared_rooms]) / len(df)

# print(private_percent)
# print(shared_percent)
# Out:
# Entire home/apt    0.515787
# Private room       0.454446
# Shared room        0.021213
# Hotel room         0.008554
# Name: room_type, dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exercise 3 - Grouping
#
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
#
#
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups.
#
#
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups.
#
#
# 4. Using `groupby`, find the median price for each room type in each neighbourhood_group.
#
#
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices for each room type in each neighbourhood_group.

# %%
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
# df.groupby('neighbourhood_group').count()

listings = df.groupby('neighbourhood_group')
listings['neighbourhood_group'].count()
# Out:
# neighbourhood_group
# Bronx             1183
# Brooklyn         18632
# Manhattan        20580
# Queens            5791
# Staten Island      341
# Name: neighbourhood_group, dtype: int64

# %%
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups. 
df.groupby('neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx             92.751479
# Brooklyn         120.225258
# Manhattan        191.880466
# Queens            99.754965
# Staten Island    110.947214
# Name: price, dtype: float64

# %%
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups. 
gb = df.groupby('neighbourhood_group')
gb_stats = gb['price'].agg( ['min', 'max'] )
gb_stats
# Out:
#                      min    max
# neighbourhood_group
# Bronx                 16   1404
# Brooklyn               0  10000
# Manhattan              0  10000
# Queens                 0  10000
# Staten Island         19   1200

# %%
# 4. Using `groupby`, find the mean price for each room type in each neighbourhood_group.

gb = df.groupby(['neighbourhood_group','room_type'])
gb['price'].mean()
# Out:
# neighbourhood_group  room_type
# Bronx                Entire home/apt    138.004819
#                      Private room        68.419668
#                      Shared room         66.391304
# Brooklyn             Entire home/apt    171.587687
#                      Hotel room         147.300000
#                      Private room        71.291189
#                      Shared room         57.870091
# Manhattan            Entire home/apt    231.335572
#                      Hotel room         292.515670
#                      Private room       128.277069
#                      Shared room        111.735084
# Queens               Entire home/apt    150.168900
#                      Hotel room         139.058824
#                      Private room        69.972564
#                      Shared room         89.891892
# Staten Island        Entire home/apt    151.720930
#                      Private room        70.312883
#                      Shared room         46.000000
# ...

# %%
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices 
# for each room type in each neighbourhood_group.
grouped_cols = ['neighbourhood_group', 'room_type']
gb = df.groupby(grouped_cols)
gb['price'].agg(['min', 'max', 'mean', 'median', 'std'])

#df.groupby(['neighbourhood_group','room_type'])['price'].agg( ['count', 'min', 'max', 'mean', 'median', 'std', 'sum'] )
# Out:
#                                      min    max        mean  median  \
# neighbourhood_group room_type
# Bronx               Entire home/apt   25   1404  138.004819   103.0
#                     Private room      16    700   68.419668    55.0
#                     Shared room       20    800   66.391304    44.0
# Brooklyn            Entire home/apt   20  10000  171.587687   135.0
#                     Hotel room         0    399  147.300000   129.0
#                     Private room      10   2500   71.291189    60.0
#                     Shared room       15   1500   57.870091    36.0
# Manhattan           Entire home/apt    0  10000  231.335572   165.0
#                     Hotel room         0   2211  292.515670   210.0
#                     Private room      10  10000  128.277069    80.0
#                     Shared room       10  10000  111.735084    60.0
# Queens              Entire home/apt   10  10000  150.168900   115.0
# ...

# %% [markdown]
# # Join and file saving.
# 1. Load the `prices.csv` and the `n_listings.csv`
#
#
# 2. Do join that keeps all the records for each table.
#     * Neighbourhood groups should include ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'LongIsland']
#
#
# 3. Save your joined csv as `joined.csv`
#
#
# 4. Load your saved table and see if it looks the same or different that the DataFrame you used to create it.

# %%
# 1. Load the `prices.csv` and the `n_listings.csv`

df_prices = pd.read_csv('data/prices.csv')
df_listings = pd.read_csv('data/n_listings.csv', sep=';')

# %%
# 2. Do join that keeps all the records for each table.

new_df = pd.merge(dfprices, dflistings, on='neighbourhood_group', how='outer')
new_df
# Out:
#   neighbourhood_group   mean_price  n_listings
# 0               Bronx    92.751479      1183.0
# 1            Brooklyn   120.225258     18632.0
# 2           Manhattan   191.880466     20580.0
# 3              Queens    99.754965         NaN
# 4       Staten Island   110.947214         NaN
# 5          LongIsland          NaN      4121.0

# %% [markdown]
# # Use the grammys.csv data for the next section of questions.
#
# 1. Who was won Album of the Year in 2016?
#
#
# 2. Who won Best Rap Album in 2009?
#
#
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

# %%
#  1. Who was won Album of the Year in 2016?

df = pd.read_csv('data/grammys.csv')
c1 = df.category == "Album of the Year"
c2 = df.year == 2016
c3 = df.winner == True
df[c1 & c2 & c3]
# Out:
#       year           category nominee  \
# 5505  2016  Album of the Year   1989.
#
#                                                 workers  winner
# 5505  Taylor Swift (artist/producer), Jack Antonoff ...    True

# %%
# 2. Who won Best Rap Album in 2009?

best_rap_condition = df.category == "Best Rap Album"
year_condition = df.year == 2009
winner_condition = df.winner == True
df[best_rap_condition & year_condition & winner_condition]
# Out:
#       year        category         nominee     workers  winner
# 4396  2009  Best Rap Album  Tha Carter III  Lil' Wayne    True

# %%
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

Kendrick_Lamar_nominated = df.workers == 'Kendrick Lamar'
Kendrick_Lamar_wins = df.winner == True
df[Kendrick_Lamar_nominated & Kendrick_Lamar_wins]
# Out:
#       year              category               nominee         workers  winner
# 5448  2015  Best Rap Performance                    i.  Kendrick Lamar    True
# 5596  2016        Best Rap Album  To Pimp a Butterfly.  Kendrick Lamar    True
# 5599  2016  Best Rap Performance              Alright.  Kendrick Lamar    True
# 6003  2018  Best Rap Performance               HUMBLE.  Kendrick Lamar    True

# %%
print("Lamar was nominated for", len(df[Kendrick_Lamar_nominated]), "awards and won", len(df[Kendrick_Lamar_nominated & Kendrick_Lamar_wins]))
# Out:
# Lamar was nominated for 6 awards and won 4
